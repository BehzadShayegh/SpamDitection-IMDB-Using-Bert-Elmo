# %%
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from google.colab import files
files.upload()
# !pip install -q kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !kaggle datasets download -d uciml/sms-spam-collection-dataset
# !unzip sms-spam-collection-dataset.zip
# Out:
#      <input type="file" id="files-2daa05cd-1951-4a27-b07d-c2a879a67f8f" name="files[]" multiple disabled />
#      <output id="result-2daa05cd-1951-4a27-b07d-c2a879a67f8f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading sms-spam-collection-dataset.zip to /content
#   0% 0.00/211k [00:00<?, ?B/s]
# 100% 211k/211k [00:00<00:00, 14.5MB/s]
# Archive:  sms-spam-collection-dataset.zip
#   inflating: spam.csv

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from tqdm.notebook import tqdm
nltk.download('punkt')
nltk.download('stopwords')
tokenizer = RegexpTokenizer(r'\w+')
tqdm.pandas()

MAX_LEN = 128
def make_clean(s) :
  return s

df = pd.read_csv('spam.csv', encoding = "ISO-8859-1")
df['clean'] = df['v2'].progress_apply(make_clean)
df['label'] = (df['v1']=='ham').astype(int)

random_index = np.zeros(df.shape[0]).astype(bool)
random_index[np.random.choice(df.shape[0], int(0.2*df.shape[0]))] = True
train_df, test_df = df[~random_index], df[random_index]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# HBox(children=(IntProgress(value=0, max=5572), HTML(value='')))

# %%
train_df.head()
# Out:
#      v1  ... label
# 1   ham  ...     1
# 2  spam  ...     0
# 3   ham  ...     1
# 4   ham  ...     1
# 7   ham  ...     1
#
# [5 rows x 7 columns]

# %%
import numpy as np

MAX_LEN = 128

# Create datasets (Only take up to MAX_LEN words)
train_text = train_df['clean'].tolist()
train_text = [' '.join(t.split()[0:MAX_LEN]) for t in train_text]
train_text = np.array(train_text, dtype=object)[:, np.newaxis]
train_label = train_df['label'].tolist()
test_text = test_df['clean'].tolist()
test_text = [' '.join(t.split()[0:MAX_LEN]) for t in test_text]
test_text = np.array(test_text, dtype=object)[:, np.newaxis]
test_label = test_df['label'].tolist()

# %%
from keras.engine.topology import Layer
import tensorflow_hub as hub
from keras import backend as K

class ElmoEmbeddingLayer(Layer):
    def __init__(self, **kwargs):
        self.dimensions = 1024
        self.trainable = True
        super(ElmoEmbeddingLayer, self).__init__(**kwargs)
    def build(self, input_shape):
        self.elmo = hub.Module('https://tfhub.dev/google/elmo/3', trainable=self.trainable, name="{}_module".format(self.name))
        self.trainable_weights += tf.trainable_variables(scope="^{}_module/.*".format(self.name))
        super(ElmoEmbeddingLayer, self).build(input_shape)
    def call(self, x, mask=None):
        result = self.elmo(K.squeeze(K.cast(x, tf.string), axis=1),
                      as_dict=True,
                      signature='default',
                      )['default']
        return result
    def compute_mask(self, inputs, mask=None):
        return K.not_equal(inputs, '--PAD--')
    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.dimensions)
# Out:
# Using TensorFlow backend.

# %%
from keras import layers
from keras.models import Model
from keras.optimizers import Adam

input_text = layers.Input(shape=(1,), dtype=tf.string)
embedding = ElmoEmbeddingLayer()(input_text)
dense = layers.Dense(1024, activation='relu')(embedding)
pred = layers.Dense(1, activation='sigmoid')(dense)
model = Model(inputs=[input_text], outputs=pred)
model.compile(loss='binary_crossentropy', optimizer=Adam(lr=2e-4), metrics=['accuracy'])
model.summary()
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 1)                 0
# _________________________________________________________________
# elmo_embedding_layer_1 (Elmo (None, 1024)              4
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 1,050,629
# Trainable params: 1,050,629
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.compat.v1 import keras

session = keras.backend.get_session()
init = tf.global_variables_initializer()
session.run(init)

# %%
import keras
import numpy as np
import sklearn.metrics as sklm

class Metrics(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.loss = []
        self.precision = []
        self.recall = []
        self.f1s = []
        self.accuracy = []
        self.auc = []

    def on_epoch_end(self, epoch, logs={}):
        score = np.asarray(self.model.predict(self.validation_data[0]))
        predict = np.round(np.asarray(self.model.predict(self.validation_data[0])))
        targ = self.validation_data[1]
        self.loss.append(keras.losses.binary_crossentropy(tf.convert_to_tensor(targ), tf.convert_to_tensor(predict)).eval(session=session).mean())
        self.auc.append(sklm.roc_auc_score(targ, score))
        self.precision.append(sklm.precision_score(targ, predict))
        self.recall.append(sklm.recall_score(targ, predict))
        self.f1s.append(sklm.f1_score(targ, predict))
        self.accuracy.append(sklm.accuracy_score(targ, predict))

        pd.DataFrame({
            'loss': self.loss,
            'precision': self.precision,
            'recall': self.recall,
            'f1s': self.f1s,
            'accuracy': self.accuracy,
            'auc': self.auc
        }).to_csv('recors.csv')

        return

metrics = Metrics()

# %%
model.fit(train_text, 
          train_label,
          validation_data=(test_text, test_label),
          epochs=50,
          callbacks=[metrics],
          batch_size=32)
# Out:
# Train on 4551 samples, validate on 1021 samples
# Epoch 1/50
# 4551/4551 [==============================] - 38s 8ms/step - loss: 0.1049 - accuracy: 0.9631 - val_loss: 0.0494 - val_accuracy: 0.9843
# Epoch 2/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 0.0452 - accuracy: 0.9857 - val_loss: 0.0363 - val_accuracy: 0.9882
# Epoch 3/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 0.0329 - accuracy: 0.9903 - val_loss: 0.0363 - val_accuracy: 0.9922
# Epoch 4/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 0.0262 - accuracy: 0.9923 - val_loss: 0.0288 - val_accuracy: 0.9902
# Epoch 5/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 0.0186 - accuracy: 0.9956 - val_loss: 0.0324 - val_accuracy: 0.9902
# Epoch 6/50
# 4551/4551 [==============================] - 28s 6ms/step - loss: 0.0160 - accuracy: 0.9949 - val_loss: 0.0321 - val_accuracy: 0.9882
# Epoch 7/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.0347 - val_accuracy: 0.9882
# Epoch 8/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 0.0092 - accuracy: 0.9974 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 9/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 0.0069 - accuracy: 0.9985 - val_loss: 0.0268 - val_accuracy: 0.9892
# Epoch 10/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 0.0050 - accuracy: 0.9991 - val_loss: 0.0342 - val_accuracy: 0.9892
# Epoch 11/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 0.0038 - accuracy: 0.9996 - val_loss: 0.0278 - val_accuracy: 0.9892
# Epoch 12/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.0304 - val_accuracy: 0.9902
# Epoch 13/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0315 - val_accuracy: 0.9892
# Epoch 14/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0310 - val_accuracy: 0.9902
# Epoch 15/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0324 - val_accuracy: 0.9912
# Epoch 16/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 9.8683e-04 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.9902
# Epoch 17/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 8.4386e-04 - accuracy: 1.0000 - val_loss: 0.0368 - val_accuracy: 0.9902
# Epoch 18/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 7.2995e-04 - accuracy: 1.0000 - val_loss: 0.0348 - val_accuracy: 0.9902
# Epoch 19/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 6.1560e-04 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9902
# Epoch 20/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 5.1193e-04 - accuracy: 1.0000 - val_loss: 0.0349 - val_accuracy: 0.9902
# Epoch 21/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 4.2190e-04 - accuracy: 1.0000 - val_loss: 0.0367 - val_accuracy: 0.9902
# Epoch 22/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 3.6111e-04 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9902
# Epoch 23/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 3.2445e-04 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 0.9902
# Epoch 24/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 2.9004e-04 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9902
# Epoch 25/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 2.4629e-04 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 0.9902
# Epoch 26/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 2.1070e-04 - accuracy: 1.0000 - val_loss: 0.0385 - val_accuracy: 0.9912
# Epoch 27/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 1.8340e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9902
# Epoch 28/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 1.6775e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9892
# Epoch 29/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 1.5588e-04 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9902
# Epoch 30/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 1.2981e-04 - accuracy: 1.0000 - val_loss: 0.0425 - val_accuracy: 0.9902
# Epoch 31/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 1.1448e-04 - accuracy: 1.0000 - val_loss: 0.0437 - val_accuracy: 0.9902
# Epoch 32/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 1.0807e-04 - accuracy: 1.0000 - val_loss: 0.0443 - val_accuracy: 0.9902
# Epoch 33/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 9.3074e-05 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 0.9912
# Epoch 34/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 8.5910e-05 - accuracy: 1.0000 - val_loss: 0.0438 - val_accuracy: 0.9912
# Epoch 35/50
# 4551/4551 [==============================] - 28s 6ms/step - loss: 7.5810e-05 - accuracy: 1.0000 - val_loss: 0.0456 - val_accuracy: 0.9902
# Epoch 36/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 6.8243e-05 - accuracy: 1.0000 - val_loss: 0.0446 - val_accuracy: 0.9902
# Epoch 37/50
# 4551/4551 [==============================] - 26s 6ms/step - loss: 6.1060e-05 - accuracy: 1.0000 - val_loss: 0.0470 - val_accuracy: 0.9902
# Epoch 38/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 5.4062e-05 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 0.9902
# Epoch 39/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 5.1240e-05 - accuracy: 1.0000 - val_loss: 0.0458 - val_accuracy: 0.9902
# Epoch 40/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 4.4783e-05 - accuracy: 1.0000 - val_loss: 0.0462 - val_accuracy: 0.9902
# Epoch 41/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 3.9766e-05 - accuracy: 1.0000 - val_loss: 0.0465 - val_accuracy: 0.9892
# Epoch 42/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 3.7507e-05 - accuracy: 1.0000 - val_loss: 0.0483 - val_accuracy: 0.9902
# Epoch 43/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 3.3322e-05 - accuracy: 1.0000 - val_loss: 0.0490 - val_accuracy: 0.9912
# Epoch 44/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 2.9765e-05 - accuracy: 1.0000 - val_loss: 0.0481 - val_accuracy: 0.9902
# Epoch 45/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 2.8569e-05 - accuracy: 1.0000 - val_loss: 0.0487 - val_accuracy: 0.9902
# Epoch 46/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 2.4644e-05 - accuracy: 1.0000 - val_loss: 0.0487 - val_accuracy: 0.9902
# Epoch 47/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 2.2236e-05 - accuracy: 1.0000 - val_loss: 0.0497 - val_accuracy: 0.9912
# Epoch 48/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 2.0539e-05 - accuracy: 1.0000 - val_loss: 0.0508 - val_accuracy: 0.9902
# Epoch 49/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 1.8301e-05 - accuracy: 1.0000 - val_loss: 0.0503 - val_accuracy: 0.9902
# Epoch 50/50
# 4551/4551 [==============================] - 27s 6ms/step - loss: 1.7140e-05 - accuracy: 1.0000 - val_loss: 0.0511 - val_accuracy: 0.9902
